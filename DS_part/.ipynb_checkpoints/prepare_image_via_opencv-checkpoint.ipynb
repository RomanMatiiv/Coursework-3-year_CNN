# %% [markdown]
# Источники <br>
# https://realpython.com/face-recognition-with-python/ <br>
# https://www.superdatascience.com/opencv-face-detection/

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import sys


PATH_TO_IMAGE="/Users/roman/Desktop/12.jpg"

# %%
#Загружаю фото
img=cv2.imread(PATH_TO_IMAGE)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)#Костыль

#Нахожу на нем лицо
haar_face_cascade = cv2.CascadeClassifier('/Volumes/HDD/Загрузки/FaceDetect-master/haarcascade_frontalface_default.xml')
faces = haar_face_cascade.detectMultiScale(gray_img, scaleFactor=1.2, minNeighbors=7)
print('Faces found: ', len(faces))
# Out:
# Faces found:  1

# %%
#Выделяю лицо
tmp=img.copy()
for (x, y, w, h) in faces:
    cv2.rectangle(tmp, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
plt.imshow(tmp);

# %% [markdown]
# _____
